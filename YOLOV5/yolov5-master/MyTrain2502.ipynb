# %%
# %pip install -qr requirements.txt  # install

import torch
import utils
display = utils.notebook_init()
# Out:
# YOLOv5  2023-2-25 Python-3.8.15 torch-1.13.0+cpu CPU
# Setup complete  (12 CPUs, 31.9 GB RAM, 758.6/830.1 GB disk)

# %%
# !python detect.py --weights yolov5s.pt --img 640 --conf 0.25 --source data/images
# Out:
# detect: weights=['yolov5s.pt'], source=data/images, data=data\coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs\detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5  2023-2-25 Python-3.8.15 torch-1.13.0+cpu CPU
#
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients
# image 1/2 D:\Programming\Python_prog\Diploma\YOLOV5_2502\yolov5-master\data\images\bus.jpg: 640x480 4 persons, 1 bus, 109.1ms
# image 2/2 D:\Programming\Python_prog\Diploma\YOLOV5_2502\yolov5-master\data\images\zidane.jpg: 384x640 2 persons, 2 ties, 81.0ms
# Speed: 1.0ms pre-process, 95.1ms inference, 5.5ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs\detect\exp3

# %%
#@title Select YOLOv5 🚀 logger {run: 'auto'}
#Здесь нужно создать учётную запись на clearML и войти по ключам
logger = 'ClearML' #@param ['ClearML', 'Comet', 'TensorBoard']

if logger == 'ClearML':
  # %pip install -q clearml
  import clearml; clearml.browser_login()
elif logger == 'Comet':
  # %pip install -q comet_ml
  import comet_ml; comet_ml.init()
elif logger == 'TensorBoard':
  # %load_ext tensorboard
  # %tensorboard --logdir runs/train
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
# !python train.py --img 640 --batch 16 --epochs 3 --data coco128.yaml --weights yolov5s.pt --cache
# Out:
# github: skipping check (not a git repository), for updates see https://github.com/ultralytics/yolov5
# ClearML Task: created new task id=7f41357231924a5fb42320ab22a08475
# 2023-02-25 14:19:31,142 - clearml.Task - INFO - No repository found, storing script code instead
# ClearML results page: https://app.clear.ml/projects/6d540d3863314454bcadeaeebbb081c3/experiments/7f41357231924a5fb42320ab22a08475/output/log
# ClearML Monitor: GPU monitoring failed getting GPU reading, switching off GPU monitoring
# 2023-02-25 14:24:54,765 - clearml.storage - INFO - Starting upload: runs\train\exp\weights\best.pt => https://files.clear.ml/runs%5Ctrain/Training.7f41357231924a5fb42320ab22a08475/models/best.pt
# ...

# %%
#Начальное обучение для v5l6
# !python train.py --img 640 --batch 16 --epochs 10 --data coco_custom_6labels.yaml --weights yolov5m.pt --cache
# Out:
# github: skipping check (not a git repository), for updates see https://github.com/ultralytics/yolov5
# train: weights=yolov5m.pt, cfg=, data=coco_custom_6labels.yaml, hyp=data\hyps\hyp.scratch-low.yaml, epochs=10, batch_size=16, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs\train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# YOLOv5  2023-2-25 Python-3.8.15 torch-1.13.0+cpu CPU
#
# ...

# %%
#Распознавание на тестовой выборке
# !python detect.py --weights runs/train/exp2/weights/best.pt --img 640 --conf 0.25 --source ../dataset/Dataset_only_for_test_2502/test/images
# Out:
# detect: weights=['runs/train/exp2/weights/best.pt'], source=../dataset/Dataset_only_for_test_2502/test/images, data=data\coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs\detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5  2023-2-25 Python-3.8.15 torch-1.13.0+cpu CPU
#
# Fusing layers...
# Model summary: 212 layers, 20873139 parameters, 0 gradients, 47.9 GFLOPs
# image 1/166 D:\Programming\Python_prog\Diploma\YOLOV5_2502\dataset\Dataset_only_for_test_2502\test\images\105_jpg.rf.2553d212910f1879efc58f9cf8af58c6.jpg: 640x640 1 brake, 271.0ms
# ...

# %%
#Получение оценок качества модели на тестовой выборке
# !python val.py --task test --weights runs/train/exp2/weights/best.pt --data coco_custom_6labels_test.yaml --img 640
# Out:
# val: data=D:\Programming\Python_prog\Diploma\YOLOV5_2502\yolov5-master\data\coco_custom_6labels_test.yaml, weights=['runs/train/exp2/weights/best.pt'], batch_size=32, imgsz=640, conf_thres=0.001, iou_thres=0.6, max_det=300, task=test, device=, workers=8, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=runs\val, name=exp, exist_ok=False, half=False, dnn=False
# YOLOv5  2023-2-25 Python-3.8.15 torch-1.13.0+cpu CPU
#
# Fusing layers...
# Model summary: 212 layers, 20873139 parameters, 0 gradients, 47.9 GFLOPs
#
# test: Scanning D:\Programming\Python_prog\Diploma\YOLOV5_2502\dataset\DS_AllInAll2502\labels\test.cache... 166 images, 2 backgrounds, 0 corrupt: 100%|##########| 166/166 [00:00<?, ?it/s]
# test: Scanning D:\Programming\Python_prog\Diploma\YOLOV5_2502\dataset\DS_AllInAll2502\labels\test.cache... 166 images, 2 backgrounds, 0 corrupt: 100%|##########| 166/166 [00:00<?, ?it/s]
#
# ...

# %%
#Продолжим обучать модель
# !python train.py --img 640 --batch 16 --epochs 35 --data coco_custom_6labels.yaml --weights runs/train/exp3/weights/best.pt --cache

# %%
#Снова оценим качество
# !python val.py --task test --weights runs/train/exp3/weights/best.pt --data coco_custom_6labels_test.yaml --img 640
# Out:
# val: data=D:\Programming\Python_prog\Diploma\YOLOV5_2502\yolov5-master\data\coco_custom_6labels_test.yaml, weights=['runs/train/exp3/weights/best.pt'], batch_size=32, imgsz=640, conf_thres=0.001, iou_thres=0.6, max_det=300, task=test, device=, workers=8, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=runs\val, name=exp, exist_ok=False, half=False, dnn=False
# YOLOv5  2023-2-25 Python-3.8.15 torch-1.13.0+cpu CPU
#
# Fusing layers...
# Model summary: 212 layers, 20873139 parameters, 0 gradients, 47.9 GFLOPs
#
# test: Scanning D:\Programming\Python_prog\Diploma\YOLOV5_2502\dataset\DS_AllInAll2502\labels\test.cache... 166 images, 2 backgrounds, 0 corrupt: 100%|##########| 166/166 [00:00<?, ?it/s]
# test: Scanning D:\Programming\Python_prog\Diploma\YOLOV5_2502\dataset\DS_AllInAll2502\labels\test.cache... 166 images, 2 backgrounds, 0 corrupt: 100%|##########| 166/166 [00:00<?, ?it/s]
#
# ...

# %%
#Начальное обучение для v5l6
# !python train.py --img 640 --batch 16 --epochs 35 --data coco_custom_6labels.yaml --weights yolov5l.pt --cache
# Out:
# github: skipping check (not a git repository), for updates see https://github.com/ultralytics/yolov5
# train: weights=yolov5l.pt, cfg=, data=coco_custom_6labels.yaml, hyp=data\hyps\hyp.scratch-low.yaml, epochs=35, batch_size=16, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs\train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# YOLOv5  2023-2-25 Python-3.8.15 torch-1.13.0+cpu CPU
#
# ...

# %%
#Снова оценим качество v5l6
# !python val.py --task test --weights runs/train/exp4/weights/last.pt --data coco_custom_6labels_test.yaml --img 640
# Out:
# val: data=D:\Programming\Python_prog\Diploma\YOLOV5_2502\yolov5-master\data\coco_custom_6labels_test.yaml, weights=['runs/train/exp4/weights/last.pt'], batch_size=32, imgsz=640, conf_thres=0.001, iou_thres=0.6, max_det=300, task=test, device=, workers=8, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=runs\val, name=exp, exist_ok=False, half=False, dnn=False
# YOLOv5  2023-2-25 Python-3.8.15 torch-1.13.0+cpu CPU
#
# Fusing layers...
# Model summary: 267 layers, 46135203 parameters, 0 gradients, 107.7 GFLOPs
#
# test: Scanning D:\Programming\Python_prog\Diploma\YOLOV5_2502\dataset\DS_AllInAll2502\labels\test.cache... 166 images, 2 backgrounds, 0 corrupt: 100%|##########| 166/166 [00:00<?, ?it/s]
# test: Scanning D:\Programming\Python_prog\Diploma\YOLOV5_2502\dataset\DS_AllInAll2502\labels\test.cache... 166 images, 2 backgrounds, 0 corrupt: 100%|##########| 166/166 [00:00<?, ?it/s]
#
# ...

# %%
#Продолжение обучения для v5l6 с датасетом sideOnlyIconsMulKai2403 10 эпох
# !python train.py --img 640 --batch 16 --epochs 10 --data coco_custom_9labels_2403.yaml --weights runs/train/exp4/weights/best.pt --cache
# Out:
# github: skipping check (not a git repository), for updates see https://github.com/ultralytics/yolov5
# train: weights=runs/train/exp4/weights/best.pt, cfg=, data=coco_custom_9labels_2403.yaml, hyp=data\hyps\hyp.scratch-low.yaml, epochs=10, batch_size=16, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs\train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# YOLOv5  2023-2-25 Python-3.8.15 torch-1.13.0+cpu CPU
#
# ...

# %%
#Снова оценим качество v5l6
# !python val.py --task test --weights runs/train/exp6/weights/last.pt --data coco_custom_6labels_test.yaml --img 640
